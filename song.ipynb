# %%
import pandas as pd
import numpy as np 
import nltk
from nltk import word_tokenize, sent_tokenize   
import matplotlib.pyplot as plt

# %%
def get_complexity(text):
    num_chars = len(text)
    num_words = len(word_tokenize(text))
    num_sentences = len(sent_tokenize(text))
    vocab = {x.lower() for x in word_tokenize(text)}
    return len(vocab), int(num_chars/num_words), int(num_words/num_sentences), len(vocab)/num_words

# %%
themefromasummerplace = open("1960.txt").read()
tossinandturnin = open("1961.txt").read()
strangerontheshore = open("1962.txt").read()
sugarshack = open("1963.txt").read()
iwanttoholdyourhand = open("1964.txt").read()
woolybully = open("1965.txt").read()
balladofthegreenberets = open("1966.txt").read()
tosirwithlove = open("1967.txt").read()
heyjude = open("1968.txt").read()
sugarsugar = open("1969.txt").read()
bridgeovertroubledwater = open("1970.txt").read()
joytotheworld = open("1971.txt").read()
thefirsttimeeverisawyourface = open("1972.txt").read()
tieayellowribbonroundtheoleoaktree = open("1973.txt").read()
thewaywewere = open("1974.txt").read()
lovewillkeepustogeher = open("1975.txt").read()
sillylovesongs = open("1976.txt").read()
tonightsthenight = open("1977.txt").read()
shadowdancing = open("1978.txt").read()
mysharona = open("1979.txt").read()
callmeblondie = open("1980.txt").read()
bettedaviseyes = open("1981.txt").read()
physical = open("1982.txt").read()
everybreathyoutake = open("1983.txt").read()
whendovescry = open("1984.txt").read()
carelesswhisper = open("1985.txt").read()
thatswhatfriendsarefor = open("1986.txt").read()
walklikeanegyptian = open("1987.txt").read()
faith = open("1988.txt").read()
lookaway = open("1989.txt").read()
holdon = open("1990.txt").read()
everythingido = open("1991.txt").read()
endoftheroad = open("1992.txt").read()
iwillalwaysloveyou = open("1993.txt").read()
thesign = open("1994.txt").read()
gangstasparadise = open("1995.txt").read()
macarena = open("1996.txt").read()
candleinthewind = open("1997.txt").read()
tooclose = open("1998.txt").read()
believe = open("1999.txt").read()
breathe = open("2000.txt").read()
hangingbyamoment = open("2001.txt").read()
howyouremindme = open("2002.txt").read()
indaclub = open("2003.txt").read()
yeah = open("2004.txt").read()
webelongtogether = open("2005.txt").read()
badday = open("2006.txt").read()
irreplaceable = open("2007.txt").read()
low = open("2008.txt").read()
boomboompow = open("2009.txt").read()
tiktok = open("2010.txt").read()
rollinginthedeep = open("2011.txt").read()
somebodythatiusedtoknow = open("2012.txt").read()
thriftshop = open("2013.txt").read()
happy = open("2014.txt").read()
uptownfunk = open("2015.txt").read()
loveyourself = open("2016.txt").read()
shapeofyou = open("2017.txt").read()
godsplan = open("2018.txt").read()
oldtownroad = open("2019.txt").read()
thebox = open("2020.txt").read()

# %%
print(get_complexity(themefromasummerplace))
print(get_complexity(tossinandturnin))
print(get_complexity(strangerontheshore))
print(get_complexity(sugarshack))
print(get_complexity(iwanttoholdyourhand))
print(get_complexity(woolybully))
print(get_complexity(balladofthegreenberets))
print(get_complexity(tosirwithlove))
print(get_complexity(heyjude))
print(get_complexity(sugarsugar))
print(get_complexity(bridgeovertroubledwater))
print(get_complexity(joytotheworld))
print(get_complexity(thefirsttimeeverisawyourface))
print(get_complexity(tieayellowribbonroundtheoleoaktree))
print(get_complexity(thewaywewere))
print(get_complexity(lovewillkeepustogeher))
print(get_complexity(sillylovesongs))
print(get_complexity(tonightsthenight))
print(get_complexity(shadowdancing))
print(get_complexity(mysharona))
print(get_complexity(callmeblondie))
print(get_complexity(bettedaviseyes))
print(get_complexity(physical))
print(get_complexity(everybreathyoutake))
print(get_complexity(whendovescry))
print(get_complexity(carelesswhisper))
print(get_complexity(thatswhatfriendsarefor))
print(get_complexity(walklikeanegyptian))
print(get_complexity(faith))
print(get_complexity(lookaway))
print(get_complexity(holdon))
print(get_complexity(everythingido))
print(get_complexity(endoftheroad))
print(get_complexity(iwillalwaysloveyou))
print(get_complexity(thesign))
print(get_complexity(gangstasparadise))
print(get_complexity(macarena))
print(get_complexity(candleinthewind))
print(get_complexity(tooclose))
print(get_complexity(believe))
print(get_complexity(breathe))
print(get_complexity(hangingbyamoment))
print(get_complexity(howyouremindme))
print(get_complexity(indaclub))
print(get_complexity(yeah))
print(get_complexity(webelongtogether))
print(get_complexity(badday))
print(get_complexity(irreplaceable))
print(get_complexity(low))
print(get_complexity(boomboompow))
print(get_complexity(tiktok))
print(get_complexity(rollinginthedeep))
print(get_complexity(somebodythatiusedtoknow))
print(get_complexity(thriftshop))
print(get_complexity(happy))
print(get_complexity(uptownfunk))
print(get_complexity(loveyourself))
print(get_complexity(shapeofyou))
print(get_complexity(godsplan))
print(get_complexity(oldtownroad))
print(get_complexity(thebox))
# Out:
# (60, 4, 121, 0.49586776859504134)
# (69, 4, 277, 0.2490974729241877)
# (56, 4, 33, 0.42424242424242425)
# (99, 4, 213, 0.4647887323943662)
# (40, 4, 207, 0.1932367149758454)
# (45, 4, 108, 0.4166666666666667)
# (83, 4, 153, 0.5424836601307189)
# (97, 4, 51, 0.6258064516129033)
# (103, 3, 119, 0.21593291404612158)
# (62, 4, 262, 0.2366412213740458)
# (79, 4, 179, 0.441340782122905)
# (76, 4, 280, 0.2714285714285714)
# (58, 4, 114, 0.5087719298245614)
# (90, 4, 98, 0.3050847457627119)
# (63, 4, 35, 0.6)
# (92, 4, 142, 0.32280701754385965)
# (74, 3, 385, 0.19220779220779222)
# (91, 4, 178, 0.5112359550561798)
# (96, 4, 452, 0.21238938053097345)
# (76, 4, 26, 0.2857142857142857)
# (58, 5, 126, 0.4603174603174603)
# (85, 4, 278, 0.3057553956834532)
# (80, 4, 267, 0.299625468164794)
# (75, 4, 315, 0.23809523809523808)
# (95, 4, 45, 0.260989010989011)
# (121, 4, 97, 0.309462915601023)
# (84, 4, 287, 0.2926829268292683)
# (120, 4, 147, 0.40816326530612246)
# ...

# %%
import matplotlib.pyplot as plt 
Songs = [1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
percent_vocabs = [0.50, 0.25, 0.42, 0.46, 0.19, 0.42, 0.54, 0.63, 0.22, 0.24,0.44, 0.27, 0.51, 0.3, 0.6, 0.32, 0.19, 0.51, 0.21, 0.29, 0.46, 0.31, 0.30, 0.24,0.26, 0.31, 0.30, 0.41, 0.32, 0.25, 0.23, 0.26, 0.23, 0.36, 0.27, 0.32, 0.41, 0.33, 0.16, 0.23, 0.36, 0.25, 0.22, 0.29, 0.24, 0.34, 0.28, 0.23, 0.27, 0.21, 0.27, 0.21, 0.29, 0.33, 0.17, 0.21, 0.25, 0.20, 0.33, 0.32, 0.31]
plt.plot(Songs, percent_vocabs, color ='blue', marker = 'o')
plt.xlabel('Billboard Song of the year', fontsize=14)
plt.ylabel('% of vocabulary in the lyrics', fontsize=14)
plt.show()

# %%
import textstat
textstat.set_lang("en")
print(textstat.coleman_liau_index(loveyourself))
print(textstat.linsear_write_formula(somebodythatiusedtoknow))
print(textstat.dale_chall_readability_score(callmeblondie))
print(textstat.text_standard(strangerontheshore, float_output=False))
print(textstat.difficult_words(tiktok))
textstat.difficult_words_list(tiktok)
# Out:
# 6.01
# 55.0
# 10.89
# 11th and 12th grade
# 12
# ["linin'",
#  'swagger',
#  'parties',
#  "toppin'",
#  'tryna',
#  'pedicure',
#  "gettin'",
#  'tipsy',
#  "feelin'",
#  'diddy',
#  'speakers',
#  'jagger']

# %%
texts = [('1960', open("1960.txt").read()), ('1961', open("1961.txt").read()),('1962', open("1962.txt").read()), ('1963', open("1963.txt").read()), ('1964', open("1964.txt").read()), ('1965', open("1965.txt").read()), ('1966', open("1966.txt").read()), ('1967', open("1967.txt").read()), ('1968', open("1968.txt").read()), ('1969', open("1969.txt").read()), ('1970', open("1970.txt").read()),('1971', open("1971.txt").read()),('1972', open("1972.txt").read()), ('1973', open("1973.txt").read()), ('1974', open("1974.txt").read()), ('1975', open("1975.txt").read()), ('1976', open("1976.txt").read()), ('1977', open("1977.txt").read()), ('1978', open("1978.txt").read()), ('1979', open("1979.txt").read()), ('1980', open("1980.txt").read()), ('1981', open("1981.txt").read()), ('1982', open("1982.txt").read()), ('1983', open("1983.txt").read()), ('1984', open("1984.txt").read()), ('1985', open("1985.txt").read()), ('1986', open("1986.txt").read()), ('1987', open("1987.txt").read()), ('1988', open("1988.txt").read()), ('1989', open("1989.txt").read()), ('1990', open("1990.txt").read()), ('1991', open("1991.txt").read()), ('1992', open("1992.txt").read()), ('1993', open("1993.txt").read()), ('1994', open("1994.txt").read()), ('1995', open("1995.txt").read()), ('1996', open("1996.txt").read()), ('1997', open("1997.txt").read()), ('1998', open("1998.txt").read()), ('1999', open("1999.txt").read()),('2000', open("2000.txt").read()), ('2001', open("2001.txt").read()),('2002', open("2002.txt").read()), ('2003', open("2003.txt").read()), ('2004', open("2004.txt").read()), ('2005', open("2005.txt").read()), ('2006', open("2006.txt").read()), ('2007', open("2007.txt").read()), ('2008', open("2008.txt").read()), ('2009', open("2009.txt").read()), ('2010', open("2010.txt").read()), ('2011', open("2011.txt").read()), ('2012', open("2012.txt").read()), ('2013', open("2013.txt").read()), ('2014', open("2014.txt").read()), ('2015', open("2015.txt").read()), ('2016', open("2016.txt").read()), ('2017', open("2017.txt").read()), ('2018', open("2018.txt").read()), ('2019', open("2019.txt").read()), ('2020', open("2020.txt").read())]

for text in texts:
    (vocab, word_size, sent_size, vocab_to_text) = get_complexity(text[1])
    print("{0:15s}\t{1:1.2f}\t{2:1.2f}\t{3:1.2f}\t{4:1.2f}".format(text[0], vocab, word_size, sent_size, vocab_to_text))
# Out:
# 1960           	60.00	4.00	121.00	0.50
# 1961           	69.00	4.00	277.00	0.25
# 1962           	56.00	4.00	33.00	0.42
# 1963           	99.00	4.00	213.00	0.46
# 1964           	40.00	4.00	207.00	0.19
# 1965           	45.00	4.00	108.00	0.42
# 1966           	83.00	4.00	153.00	0.54
# 1967           	97.00	4.00	51.00	0.63
# 1968           	103.00	3.00	119.00	0.22
# 1969           	62.00	4.00	262.00	0.24
# 1970           	79.00	4.00	179.00	0.44
# 1971           	76.00	4.00	280.00	0.27
# 1972           	58.00	4.00	114.00	0.51
# 1973           	90.00	4.00	98.00	0.31
# 1974           	63.00	4.00	35.00	0.60
# 1975           	92.00	4.00	142.00	0.32
# 1976           	74.00	3.00	385.00	0.19
# 1977           	91.00	4.00	178.00	0.51
# 1978           	96.00	4.00	452.00	0.21
# 1979           	76.00	4.00	26.00	0.29
# 1980           	58.00	5.00	126.00	0.46
# 1981           	85.00	4.00	278.00	0.31
# 1982           	80.00	4.00	267.00	0.30
# 1983           	75.00	4.00	315.00	0.24
# ...

# %%
texts = [('1960', open("1960.txt").read()), ('1961', open("1961.txt").read()),('1962', open("1962.txt").read()), ('1963', open("1963.txt").read()), ('1964', open("1964.txt").read()), ('1965', open("1965.txt").read()), ('1966', open("1966.txt").read()), ('1967', open("1967.txt").read()), ('1968', open("1968.txt").read()), ('1969', open("1969.txt").read()), ('1970', open("1970.txt").read()),('1971', open("1971.txt").read()),('1972', open("1972.txt").read()), ('1973', open("1973.txt").read()), ('1974', open("1974.txt").read()), ('1975', open("1975.txt").read()), ('1976', open("1976.txt").read()), ('1977', open("1977.txt").read()), ('1978', open("1978.txt").read()), ('1979', open("1979.txt").read()), ('1980', open("1980.txt").read()), ('1981', open("1981.txt").read()), ('1982', open("1982.txt").read()), ('1983', open("1983.txt").read()), ('1984', open("1984.txt").read()), ('1985', open("1985.txt").read()), ('1986', open("1986.txt").read()), ('1987', open("1987.txt").read()), ('1988', open("1988.txt").read()), ('1989', open("1989.txt").read()), ('1990', open("1990.txt").read()), ('1991', open("1991.txt").read()), ('1992', open("1992.txt").read()), ('1993', open("1993.txt").read()), ('1994', open("1994.txt").read()), ('1995', open("1995.txt").read()), ('1996', open("1996.txt").read()), ('1997', open("1997.txt").read()), ('1998', open("1998.txt").read()), ('1999', open("1999.txt").read()),('2000', open("2000.txt").read()), ('2001', open("2001.txt").read()),('2002', open("2002.txt").read()), ('2003', open("2003.txt").read()), ('2004', open("2004.txt").read()), ('2005', open("2005.txt").read()), ('2006', open("2006.txt").read()), ('2007', open("2007.txt").read()), ('2008', open("2008.txt").read()), ('2009', open("2009.txt").read()), ('2010', open("2010.txt").read()), ('2011', open("2011.txt").read()), ('2012', open("2012.txt").read()), ('2013', open("2013.txt").read()), ('2014', open("2014.txt").read()), ('2015', open("2015.txt").read()), ('2016', open("2016.txt").read()), ('2017', open("2017.txt").read()), ('2018', open("2018.txt").read()), ('2019', open("2019.txt").read()), ('2020', open("2020.txt").read())]

for text in texts:
    (lyricsgrade) = textstat.flesch_kincaid_grade(text[1])
    print(text[0], lyricsgrade)
    plt.plot(text[0], lyricsgrade, color='blue', marker='o')
# Out:
# 1960 39.9
# 1961 91.0
# 1962 7.4
# 1963 70.3
# 1964 64.9
# 1965 33.7
# 1966 54.3
# 1967 15.0
# 1968 42.3
# 1969 85.9
# 1970 60.2
# 1971 101.5
# 1972 40.3
# 1973 30.0
# 1974 18.1
# 1975 44.2
# 1976 121.4
# 1977 58.6
# 1978 156.9
# 1979 14.6
# 1980 47.7
# 1981 89.8
# 1982 87.1
# 1983 98.8
# 1984 26.4
# 1985 30.3
# 1986 96.4
# 1987 47.3
# 1988 114.4
# 1989 143.2
# 1990 15.9
# 1991 96.8
# 1992 31.6
# 1993 55.5
# 1994 9.2
# 1995 188.9
# 1996 34.8
# 1997 115.2
# 1998 199.0
# 1999 9.5
# 2000 96.1
# 2001 102.7
# 2002 143.6
# 2003 63.0
# 2004 4.5
# 2005 163.5
# 2006 33.6
# 2007 211.1
# 2008 260.2
# 2009 190.0
# 2010 86.5
# 2011 195.9
# 2012 139.0
# 2013 23.8
# 2014 191.6
# 2015 34.0
# 2016 171.3
# 2017 243.5
# 2018 64.5
# 2019 75.4
# 2020 67.1

# %%
ttokens = nltk.word_tokenize(boomboompow)  
ttext = nltk.Text(ttokens) 
ttext.dispersion_plot(["sex", "nigga", "bitch", "ass", "fuck", "damn"])
